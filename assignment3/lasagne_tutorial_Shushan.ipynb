# %% [markdown]
# # lasagne
# * lasagne is a library for neural network building and training
# * it's a low-level library with almost seamless integration with theano
#
# For a demo we shall solve the same digit recognition problem, but at a different scale
# * images are now 28x28
# * 10 different digits
# * 50k samples

# %%
import numpy as np
import theano
import theano.tensor as T
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mnist import load_dataset
X_train,y_train,X_val,y_val,X_test,y_test = load_dataset()

print(X_train.shape,y_train.shape)
# Out:
# (50000, 1, 28, 28) (50000,)

# %%
input_X = T.tensor4("X")

#input dimention (None means "Arbitrary" and only works at  the first axes [samples])
input_shape = [None,1,28,28]

target_y = T.vector("target Y integer",dtype='int32')

# %% [markdown]
# Defining network architecture

# %%
import lasagne
from lasagne.layers import *

#Input layer (auxilary)
l = InputLayer(shape = input_shape,input_var=input_X)

#fully connected layer, that takes input layer and applies 50 neurons to it.
# nonlinearity here is sigmoid as in logistic regression
# you can give a name to each layer (optional)
l = lasagne.layers.Conv2DLayer(l, num_filters=32, filter_size=(2,2), nonlinearity=lasagne.nonlinearities.rectify)
#l = DenseLayer(l,num_units=100,nonlinearity = lasagne.nonlinearitis.tanh)
l = lasagne.layers.MaxPool2DLayer(l, pool_size=(2,2))
l = lasagne.layers.Conv2DLayer(l, num_filters=16, filter_size=(4,4), nonlinearity=lasagne.nonlinearities.rectify)

l = DenseLayer(l,num_units=128,nonlinearity = lasagne.nonlinearities.rectify)

#fully connected output layer that takes dense_1 as input and has 10 neurons (1 for each digit)
#We use softmax nonlinearity to make probabilities add up to 1
l_out = DenseLayer(l,num_units = 10,nonlinearity=lasagne.nonlinearities.softmax)

# %%
#network prediction (theano-transformation)
y_predicted = lasagne.layers.get_output(l_out)

# %%
#all network weights (shared variables)
all_weights = lasagne.layers.get_all_params(l_out)
print(all_weights)
# Out:
# [W, b, W, b, W, b, W, b]

# %% [markdown]
# ### Than you could simply
# * define loss function manually
# * compute error gradient over all weights
# * define updates
# * But that's a whole lot of work and life's short
#   * not to mention life's too short to wait for SGD to converge
#
# Instead, we shall use Lasagne builtins

# %%
#Mean categorical crossentropy as a loss function - similar to logistic loss but for multiclass targets
loss = lasagne.objectives.categorical_crossentropy(y_predicted,target_y).mean()

#prediction accuracy
accuracy = lasagne.objectives.categorical_accuracy(y_predicted,target_y).mean()

#This function computes gradient AND composes weight updates just like you did earlier
updates_adamax = lasagne.updates.adamax(loss, all_weights,learning_rate=0.01)

# %%
#function that computes loss and updates weights
train_fun = theano.function([input_X,target_y],[loss,accuracy],updates= updates_adamax)

#function that just computes accuracy
accuracy_fun = theano.function([input_X,target_y],accuracy)

# %% [markdown]
# ### That's all, now let's train it!
# * We got a lot of data, so it's recommended that you use SGD
# * So let's implement a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training

#Parameters
# inputs - a tensor of images with shape (many, 1, 28, 28), e.g. X_train
# outputs - a vector of answers for corresponding images e.g. Y_train
#batch_size - a single number - the intended size of each batches

def iterate_minibatches(inputs, targets, batchsize):
    assert len(inputs) == len(targets)
    indices = np.arange(len(inputs))
    np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        excerpt = indices[start_idx:start_idx + batchsize]
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Training loop

# %%
import time

num_epochs = 100 #amount of passes through the data

batch_size = 50 #number of samples processed at each function call

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train,batch_size):
        inputs, targets = batch
        train_err_batch, train_acc_batch= train_fun(inputs, targets)
        train_err += train_err_batch
        train_acc += train_acc_batch
        train_batches += 1

    # And a full pass over the validation data:
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_val, y_val, batch_size):
        inputs, targets = batch
        val_acc += accuracy_fun(inputs, targets)
        val_batches += 1

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))

    print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
    print("  train accuracy:\t\t{:.2f} %".format(
        train_acc / train_batches * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(val_acc / val_batches * 100))
# Out:
# Epoch 1 of 100 took 125.211s
#   training loss (in-iteration):		0.059842
#   train accuracy:		98.11 %
#   validation accuracy:		98.17 %
# Epoch 2 of 100 took 131.039s
#   training loss (in-iteration):		0.039275
#   train accuracy:		98.78 %
#   validation accuracy:		98.50 %
# Epoch 3 of 100 took 134.381s
#   training loss (in-iteration):		0.027683
#   train accuracy:		99.13 %
#   validation accuracy:		98.84 %
# Epoch 4 of 100 took 135.870s
#   training loss (in-iteration):		0.019563
#   train accuracy:		99.37 %
#   validation accuracy:		98.76 %
# Epoch 5 of 100 took 136.909s
#   training loss (in-iteration):		0.013624
#   train accuracy:		99.57 %
#   validation accuracy:		98.83 %
# Epoch 6 of 100 took 134.291s
#   training loss (in-iteration):		0.009235
#   train accuracy:		99.70 %
#   validation accuracy:		98.90 %
# Epoch 7 of 100 took 136.226s
#   training loss (in-iteration):		0.008959
#   train accuracy:		99.68 %
#   validation accuracy:		98.92 %
# Epoch 8 of 100 took 144.088s
#   training loss (in-iteration):		0.006078
#   train accuracy:		99.78 %
#   validation accuracy:		98.83 %
# Epoch 9 of 100 took 144.015s
#   training loss (in-iteration):		0.004731
#   train accuracy:		99.84 %
#   validation accuracy:		98.82 %
# Epoch 10 of 100 took 142.978s
#   training loss (in-iteration):		0.003799
#   train accuracy:		99.87 %
#   validation accuracy:		98.84 %
# Epoch 11 of 100 took 147.025s
#   training loss (in-iteration):		0.002786
#   train accuracy:		99.90 %
#   validation accuracy:		98.79 %
# Epoch 12 of 100 took 143.744s
#   training loss (in-iteration):		0.003017
#   train accuracy:		99.90 %
#   validation accuracy:		98.76 %
# Epoch 13 of 100 took 144.929s
#   training loss (in-iteration):		0.002180
#   train accuracy:		99.93 %
#   validation accuracy:		98.98 %
# Epoch 14 of 100 took 144.002s
#   training loss (in-iteration):		0.002478
#   train accuracy:		99.92 %
#   validation accuracy:		98.82 %
# Epoch 15 of 100 took 143.864s
#   training loss (in-iteration):		0.002170
#   train accuracy:		99.92 %
#   validation accuracy:		98.92 %
# Epoch 16 of 100 took 143.914s
#   training loss (in-iteration):		0.001017
#   train accuracy:		99.96 %
#   validation accuracy:		98.87 %
# Epoch 17 of 100 took 143.673s
#   training loss (in-iteration):		0.001160
#   train accuracy:		99.96 %
#   validation accuracy:		98.87 %
# Epoch 18 of 100 took 143.931s
#   training loss (in-iteration):		0.001624
#   train accuracy:		99.95 %
#   validation accuracy:		98.76 %
# Epoch 19 of 100 took 147.831s
#   training loss (in-iteration):		0.001335
#   train accuracy:		99.96 %
#   validation accuracy:		98.86 %
# Epoch 20 of 100 took 148.013s
#   training loss (in-iteration):		0.000953
#   train accuracy:		99.97 %
#   validation accuracy:		98.81 %
# Epoch 21 of 100 took 149.062s
#   training loss (in-iteration):		0.001151
#   train accuracy:		99.96 %
#   validation accuracy:		98.84 %
# Epoch 22 of 100 took 144.207s
#   training loss (in-iteration):		0.001382
#   train accuracy:		99.95 %
#   validation accuracy:		98.87 %
# Epoch 23 of 100 took 144.039s
#   training loss (in-iteration):		0.001239
#   train accuracy:		99.96 %
#   validation accuracy:		98.94 %
# Epoch 24 of 100 took 146.282s
#   training loss (in-iteration):		0.000601
#   train accuracy:		99.99 %
#   validation accuracy:		98.86 %
# Epoch 25 of 100 took 146.479s
#   training loss (in-iteration):		0.000584
#   train accuracy:		99.98 %
#   validation accuracy:		98.86 %
# Epoch 26 of 100 took 143.480s
#   training loss (in-iteration):		0.001042
#   train accuracy:		99.96 %
#   validation accuracy:		98.85 %
# Epoch 27 of 100 took 143.663s
#   training loss (in-iteration):		0.000522
#   train accuracy:		99.98 %
#   validation accuracy:		98.82 %
# Epoch 28 of 100 took 143.300s
#   training loss (in-iteration):		0.001363
#   train accuracy:		99.95 %
#   validation accuracy:		98.81 %
# Epoch 29 of 100 took 143.358s
#   training loss (in-iteration):		0.000835
#   train accuracy:		99.97 %
#   validation accuracy:		98.82 %
# Epoch 30 of 100 took 145.686s
#   training loss (in-iteration):		0.000667
#   train accuracy:		99.98 %
#   validation accuracy:		98.82 %
# Epoch 31 of 100 took 143.224s
#   training loss (in-iteration):		0.001018
#   train accuracy:		99.97 %
#   validation accuracy:		98.86 %
# Epoch 32 of 100 took 143.166s
#   training loss (in-iteration):		0.000405
#   train accuracy:		99.99 %
#   validation accuracy:		98.93 %
# Epoch 33 of 100 took 143.026s
#   training loss (in-iteration):		0.000900
#   train accuracy:		99.97 %
#   validation accuracy:		98.86 %
# Epoch 34 of 100 took 142.968s
#   training loss (in-iteration):		0.000408
#   train accuracy:		99.99 %
#   validation accuracy:		98.69 %
# Epoch 35 of 100 took 143.075s
#   training loss (in-iteration):		0.000877
#   train accuracy:		99.98 %
#   validation accuracy:		98.72 %
# Epoch 36 of 100 took 142.449s
#   training loss (in-iteration):		0.000342
#   train accuracy:		99.99 %
#   validation accuracy:		98.95 %
# Epoch 37 of 100 took 143.054s
#   training loss (in-iteration):		0.000009
#   train accuracy:		100.00 %
#   validation accuracy:		98.92 %
# Epoch 38 of 100 took 142.150s
#   training loss (in-iteration):		0.000001
#   train accuracy:		100.00 %
#   validation accuracy:		98.91 %
# Epoch 39 of 100 took 142.857s
#   training loss (in-iteration):		0.000001
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 40 of 100 took 142.818s
#   training loss (in-iteration):		0.000236
#   train accuracy:		100.00 %
#   validation accuracy:		98.91 %
# Epoch 41 of 100 took 142.903s
#   training loss (in-iteration):		0.000789
#   train accuracy:		99.97 %
#   validation accuracy:		98.72 %
# Epoch 42 of 100 took 142.477s
#   training loss (in-iteration):		0.000637
#   train accuracy:		99.98 %
#   validation accuracy:		98.76 %
# Epoch 43 of 100 took 143.351s
#   training loss (in-iteration):		0.000569
#   train accuracy:		99.99 %
#   validation accuracy:		98.80 %
# Epoch 44 of 100 took 147.769s
#   training loss (in-iteration):		0.000796
#   train accuracy:		99.98 %
#   validation accuracy:		98.75 %
# Epoch 45 of 100 took 143.357s
#   training loss (in-iteration):		0.000036
#   train accuracy:		100.00 %
#   validation accuracy:		98.79 %
# Epoch 46 of 100 took 142.838s
#   training loss (in-iteration):		0.000149
#   train accuracy:		100.00 %
#   validation accuracy:		98.90 %
# Epoch 47 of 100 took 142.488s
#   training loss (in-iteration):		0.000153
#   train accuracy:		99.99 %
#   validation accuracy:		98.78 %
# Epoch 48 of 100 took 141.977s
#   training loss (in-iteration):		0.001690
#   train accuracy:		99.94 %
#   validation accuracy:		99.01 %
# Epoch 49 of 100 took 142.215s
#   training loss (in-iteration):		0.000194
#   train accuracy:		99.99 %
#   validation accuracy:		98.95 %
# Epoch 50 of 100 took 142.159s
#   training loss (in-iteration):		0.000004
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 51 of 100 took 140.446s
#   training loss (in-iteration):		0.000001
#   train accuracy:		100.00 %
#   validation accuracy:		98.97 %
# Epoch 52 of 100 took 141.077s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.92 %
# Epoch 53 of 100 took 141.278s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.92 %
# Epoch 54 of 100 took 140.892s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.96 %
# Epoch 55 of 100 took 139.310s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 56 of 100 took 140.535s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 57 of 100 took 138.563s
#   training loss (in-iteration):		0.001209
#   train accuracy:		99.96 %
#   validation accuracy:		98.80 %
# Epoch 58 of 100 took 139.165s
#   training loss (in-iteration):		0.000782
#   train accuracy:		99.97 %
#   validation accuracy:		98.98 %
# Epoch 59 of 100 took 140.254s
#   training loss (in-iteration):		0.000783
#   train accuracy:		99.98 %
#   validation accuracy:		98.97 %
# Epoch 60 of 100 took 137.765s
#   training loss (in-iteration):		0.000620
#   train accuracy:		99.98 %
#   validation accuracy:		98.64 %
# Epoch 61 of 100 took 140.056s
#   training loss (in-iteration):		0.000711
#   train accuracy:		99.98 %
#   validation accuracy:		98.88 %
# Epoch 62 of 100 took 138.362s
#   training loss (in-iteration):		0.000071
#   train accuracy:		100.00 %
#   validation accuracy:		98.84 %
# Epoch 63 of 100 took 138.235s
#   training loss (in-iteration):		0.000602
#   train accuracy:		99.98 %
#   validation accuracy:		98.85 %
# Epoch 64 of 100 took 137.494s
#   training loss (in-iteration):		0.000236
#   train accuracy:		99.99 %
#   validation accuracy:		98.88 %
# Epoch 65 of 100 took 139.725s
#   training loss (in-iteration):		0.000003
#   train accuracy:		100.00 %
#   validation accuracy:		98.91 %
# Epoch 66 of 100 took 137.925s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 67 of 100 took 139.313s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 68 of 100 took 140.118s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.97 %
# Epoch 69 of 100 took 138.083s
#   training loss (in-iteration):		0.000148
#   train accuracy:		99.99 %
#   validation accuracy:		98.97 %
# Epoch 70 of 100 took 138.932s
#   training loss (in-iteration):		0.000190
#   train accuracy:		99.99 %
#   validation accuracy:		98.85 %
# Epoch 71 of 100 took 137.895s
#   training loss (in-iteration):		0.001067
#   train accuracy:		99.97 %
#   validation accuracy:		98.81 %
# Epoch 72 of 100 took 138.232s
#   training loss (in-iteration):		0.000745
#   train accuracy:		99.98 %
#   validation accuracy:		99.00 %
# Epoch 73 of 100 took 138.615s
#   training loss (in-iteration):		0.000077
#   train accuracy:		100.00 %
#   validation accuracy:		98.84 %
# Epoch 74 of 100 took 138.902s
#   training loss (in-iteration):		0.000004
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 75 of 100 took 138.153s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.98 %
# Epoch 76 of 100 took 138.016s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.98 %
# Epoch 77 of 100 took 138.620s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.00 %
# Epoch 78 of 100 took 138.364s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.00 %
# Epoch 79 of 100 took 138.055s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.01 %
# Epoch 80 of 100 took 137.346s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.99 %
# Epoch 81 of 100 took 137.607s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.00 %
# Epoch 82 of 100 took 138.300s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.01 %
# Epoch 83 of 100 took 138.631s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.98 %
# Epoch 84 of 100 took 137.828s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.01 %
# Epoch 85 of 100 took 137.448s
#   training loss (in-iteration):		0.001695
#   train accuracy:		99.96 %
#   validation accuracy:		98.84 %
# Epoch 86 of 100 took 136.956s
#   training loss (in-iteration):		0.000738
#   train accuracy:		99.99 %
#   validation accuracy:		98.91 %
# Epoch 87 of 100 took 137.414s
#   training loss (in-iteration):		0.000049
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 88 of 100 took 138.470s
#   training loss (in-iteration):		0.000307
#   train accuracy:		99.99 %
#   validation accuracy:		98.94 %
# Epoch 89 of 100 took 137.686s
#   training loss (in-iteration):		0.000276
#   train accuracy:		99.99 %
#   validation accuracy:		98.97 %
# Epoch 90 of 100 took 137.406s
#   training loss (in-iteration):		0.000005
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 91 of 100 took 137.305s
#   training loss (in-iteration):		0.000214
#   train accuracy:		99.99 %
#   validation accuracy:		98.79 %
# Epoch 92 of 100 took 136.959s
#   training loss (in-iteration):		0.000719
#   train accuracy:		99.98 %
#   validation accuracy:		98.88 %
# Epoch 93 of 100 took 136.340s
#   training loss (in-iteration):		0.000018
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 94 of 100 took 137.232s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.94 %
# Epoch 95 of 100 took 137.439s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.95 %
# Epoch 96 of 100 took 136.287s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.96 %
# Epoch 97 of 100 took 136.929s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.96 %
# Epoch 98 of 100 took 136.172s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.96 %
# Epoch 99 of 100 took 136.652s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		98.98 %
# Epoch 100 of 100 took 136.594s
#   training loss (in-iteration):		0.000000
#   train accuracy:		100.00 %
#   validation accuracy:		99.00 %

# %%
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500):
    inputs, targets = batch
    acc = accuracy_fun(inputs, targets)
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

if test_acc / test_batches * 100 > 99:
    print ("Achievement unlocked: 80lvl Warlock!")
else:
    print ("We need more magic!")
# Out:
# Final results:
#   test accuracy:		98.89 %
# We need more magic!

# %% [markdown]
# # Now improve it!
#
# * Moar layers!
# * Moar units!
# * Different nonlinearities!
